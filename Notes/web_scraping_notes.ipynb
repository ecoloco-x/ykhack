# %%
import requests
from bs4 import BeautifulSoup


url = "https://en.wikipedia.org/wiki/Beautiful_Soup_(HTML_parser)"
html = requests.get(url).content
html[0:600]


soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Beautiful Soup (HTML parser) - Wikipedia</title>
# ...

# %%
table = soup.find('table', class_='infobox vevent')
table
# Out:
# <table class="infobox vevent"><caption class="infobox-title summary">Beautiful Soup</caption><tbody><tr><th class="infobox-label" scope="row" style="white-space: nowrap;"><a href="/wiki/Programmer" title="Programmer">Original author(s)</a></th><td class="infobox-data">Leonard Richardson</td></tr><tr><th class="infobox-label" scope="row" style="white-space: nowrap;">Initial release</th><td class="infobox-data">2004<span style="display:none"> (<span class="bday dtstart published updated">2004</span>)</span></td></tr><tr style="display: none;"><td class="infobox-full-data" colspan="2"><link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"/></td></tr><tr><th class="infobox-label" scope="row" style="white-space: nowrap;"><a href="/wiki/Software_release_life_cycle" title="Software release life cycle">Stable release</a></th><td class="infobox-data"><div style="margin:0px;">4.11.1<sup class="reference" id="cite_ref-wikidata-e7a10b268ba7d0390752d415cf48ad42b56a0494
# ...

# %%
url = table.find('th', text = 'Website').next_sibling.span.a['href']
url
# Out:
# 'https://www.crummy.com/software/BeautifulSoup/'

# %%
stable_release = table.find('th', text = 'Stable release').next_sibling.text

# %%
stable_release
# Out:
# '4.11.1[1]\xa0\n   / 8 April 2022; 9 months ago\xa0(8 April 2022)'

# %%
<td class="infobox-data">
<div style="margin:0px;">
4.11.1
<sup class="reference" id="cite_ref-wikidata-e7a10b268ba7d0390752d415cf48ad42b56a0494-v3_1-0"><a href="#cite_note-wikidata-e7a10b268ba7d0390752d415cf48ad42b56a0494-v3-1">[1]</a></sup>

<a href="https://www.wikidata.org/wiki/Q2893296?uselang=en#P348" title="Edit this on Wikidata">
<img alt="Edit this on Wikidata" data-file-height="20" data-file-width="20" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" style="vertical-align: text-top" width="10"/></a>

   / 8 April 2022
    <span class="noprint">; 9 months ago</span>
    <span style="display:none"> (<span class="bday dtstart published updated">8 April 2022</span>)</span></div></td>

# %%
stable_release_2 = table.find('td')

# %%
stable_release_2
# Out:
# <td class="infobox-data">Leonard Richardson</td>
